# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/tobigs_conference/report_crawling/csv_file/all_set_df.csv')

# %%
df.head()
# Out:
#          date   IT   건설  건자재   게임   광고   교육   금융   기계   기타  ...   증권 지주회사  \
# 0  2007-11-12  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN
# 1  2007-11-13  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN
# 2  2007-12-04  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN
# 3  2007-12-05  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN
# 4  2007-12-18  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN
#
#                                                 철강금속  타이어   통신 항공운송   해운  홈쇼핑  \
# 0                                                NaN  NaN  NaN  NaN  NaN  NaN
# 1                                                NaN  NaN  NaN  NaN  NaN  NaN
# 2                                                NaN  NaN  NaN  NaN  NaN  NaN
# 3  최근 세계 철강 시황 점검: 철강-강세, 비철-약세\n\n    철강금속 : 비중확...  NaN  NaN  NaN  NaN  NaN
# 4                                                NaN  NaN  NaN  NaN  NaN  NaN
#
# ...

# %%
# 데이터프레임의 구조를 출력
print("데이터프레임의 구조:")
print(df.shape)

# na가 아닌 값들의 개수를 출력
non_na_count = df.count().sum()
print(f"\nna가 아닌 값들의 개수: {non_na_count}")
# Out:
# 데이터프레임의 구조:
# (3918, 43)
#
# na가 아닌 값들의 개수: 27724

# %%
final = pd.read_csv('/content/drive/MyDrive/tobigs_conference/report_crawling/csv_file/semi_final_df.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-22-7b29714594fb> in <cell line: 1>()
# ----> 1 final = pd.read_csv('/content/drive/MyDrive/tobigs_conference/report_crawling/csv_file/semi_final_df.csv')
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
semi_final.head()
# Out:
#    Unnamed: 0 industry      date kapital                        title  \
# 0           0       건설  20231123    하나증권  해외EPC 3Q23 실발 분석: 한가닥씩 한 수주
# 1           1       건설  20231122    교보증권                건설/부동산 Weekly
# 2           2       건설  20231121    하나증권       금리 하락에 상승한 주택주, 추격은 금물
# 3           3       건설  20231120  이베스트증권          건설: 부동산 Weekly Data
# 4           4       건설  20231115    교보증권                건설/부동산 Weekly
#
#              pdf                                            content
# 0  1700697075313  \n \n\n3Q23 실적 분위기: 호조전반적인 글로벌 EPC사의 23년 3분기 실...
# 1  1700610083064  \n \n\n건설/부동산 Weekly News- '집값 2차 조정기 오나'... 반...
# 2  1700525881852  \n \n\n주간 투자 전략 및 이슈 점검- 수익률은 건설업이 코스피 대비 1.2%...
# 3  1700439602849  \n \n\n이번주 Comment-전국 아파트 매매가격지수는 90.2로 -5.5% ...
# 4  1700006327040  \n \n\n건설/부동산 Weekly News- 서울 아파트 매물 8만건 쌓여…거래...

# %%
# 'title'과 'content'를 합쳐 'title_content' 열 생성
semi_final['title_content'] = semi_final['title'] + '\n\n' + semi_final['content']

# 'title'과 'content' 열 삭제
semi_final_df = semi_final.drop(['title', 'content'], axis=1)

# %%
semi_final_df.to_csv('/content/drive/MyDrive/tobigs_conference/report_crawling/csv_file/content_title.csv')

# %%
semi_final_df.shape
# Out:
# (31451, 6)

# %% [markdown]
# # 같은 날 같은 산업에 쓰여진 레포트가 2개 이상인 경우들이 있는것으로 판단됨

# %%
semi_final_df.head()
# Out:
#    Unnamed: 0 industry      date kapital            pdf  \
# 0           0       건설  20231123    하나증권  1700697075313
# 1           1       건설  20231122    교보증권  1700610083064
# 2           2       건설  20231121    하나증권  1700525881852
# 3           3       건설  20231120  이베스트증권  1700439602849
# 4           4       건설  20231115    교보증권  1700006327040
#
#                                        title_content
# 0  해외EPC 3Q23 실발 분석: 한가닥씩 한 수주\n\n\n \n\n3Q23 실적 ...
# 1  건설/부동산 Weekly\n\n\n \n\n건설/부동산 Weekly News- '집...
# 2  금리 하락에 상승한 주택주, 추격은 금물\n\n\n \n\n주간 투자 전략 및 이슈...
# 3  건설: 부동산 Weekly Data\n\n\n \n\n이번주 Comment-전국 아...
# 4  건설/부동산 Weekly\n\n\n \n\n건설/부동산 Weekly News- 서울...

# %%
semi_final.columns
# Out:
# Index(['Unnamed: 0', 'industry', 'date', 'kapital', 'title', 'pdf', 'content',
#        'title_content'],
#       dtype='object')

# %%
combined_df = pd.read_csv('/content/drive/MyDrive/tobigs_conference/report_crawling/csv_file/final_df.csv')

# %%
combined_df.head()
# Out:
#    Unnamed: 0 industry      date kapital                        title  \
# 0           0       건설  20231123    하나증권  해외EPC 3Q23 실발 분석: 한가닥씩 한 수주
# 1           1       건설  20231122    교보증권                건설/부동산 Weekly
# 2           2       건설  20231121    하나증권       금리 하락에 상승한 주택주, 추격은 금물
# 3           3       건설  20231120  이베스트증권          건설: 부동산 Weekly Data
# 4           4       건설  20231115    교보증권                건설/부동산 Weekly
#
#              pdf                                            content
# 0  1700697075313  \n \n\n3Q23 실적 분위기: 호조전반적인 글로벌 EPC사의 23년 3분기 실...
# 1  1700610083064  \n \n\n건설/부동산 Weekly News- '집값 2차 조정기 오나'... 반...
# 2  1700525881852  \n \n\n주간 투자 전략 및 이슈 점검- 수익률은 건설업이 코스피 대비 1.2%...
# 3  1700439602849  \n \n\n이번주 Comment-전국 아파트 매매가격지수는 90.2로 -5.5% ...
# 4  1700006327040  \n \n\n건설/부동산 Weekly News- 서울 아파트 매물 8만건 쌓여…거래...

# %%
# '\n'으로 split하고 'pdf'로 끝나는 부분 제거
combined_df['content'] = combined_df['content'].str.split('\n').apply(lambda x: ' '.join([item for item in x if not item.endswith('pdf')]))

# 결과 출력
combined_df.head()
# Out:
#    Unnamed: 0 industry      date kapital                        title  \
# 0           0       건설  20231123    하나증권  해외EPC 3Q23 실발 분석: 한가닥씩 한 수주
# 1           1       건설  20231122    교보증권                건설/부동산 Weekly
# 2           2       건설  20231121    하나증권       금리 하락에 상승한 주택주, 추격은 금물
# 3           3       건설  20231120  이베스트증권          건설: 부동산 Weekly Data
# 4           4       건설  20231115    교보증권                건설/부동산 Weekly
#
#              pdf                                            content
# 0  1700697075313      3Q23 실적 분위기: 호조전반적인 글로벌 EPC사의 23년 3분기 실적은 ...
# 1  1700610083064      건설/부동산 Weekly News- '집값 2차 조정기 오나'... 반등하던...
# 2  1700525881852      주간 투자 전략 및 이슈 점검- 수익률은 건설업이 코스피 대비 1.2%p 아...
# 3  1700439602849      이번주 Comment-전국 아파트 매매가격지수는 90.2로 -5.5% YTD...
# 4  1700006327040      건설/부동산 Weekly News- 서울 아파트 매물 8만건 쌓여…거래절벽 ...

# %%
selected_columns = ['industry', 'date', 'title', 'content']
semi_final_df = combined_df[selected_columns]

# 'date' 열을 int에서 datetime 형식으로 변경
semi_final_df['date'] = pd.to_datetime(semi_final_df['date'], format='%Y%m%d')

semi_final_df.head()
# Out:
# <ipython-input-30-b7fb590ca8c5>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   semi_final_df['date'] = pd.to_datetime(semi_final_df['date'], format='%Y%m%d')
#   industry       date                        title  \
# 0       건설 2023-11-23  해외EPC 3Q23 실발 분석: 한가닥씩 한 수주
# 1       건설 2023-11-22                건설/부동산 Weekly
# 2       건설 2023-11-21       금리 하락에 상승한 주택주, 추격은 금물
# 3       건설 2023-11-20          건설: 부동산 Weekly Data
# 4       건설 2023-11-15                건설/부동산 Weekly
#
#                                              content
# 0      3Q23 실적 분위기: 호조전반적인 글로벌 EPC사의 23년 3분기 실적은 ...
# 1      건설/부동산 Weekly News- '집값 2차 조정기 오나'... 반등하던...
# 2      주간 투자 전략 및 이슈 점검- 수익률은 건설업이 코스피 대비 1.2%p 아...
# ...

# %%
# 'title'과 'content'를 합쳐 'title_content' 열 생성
semi_final_df['title_content'] = semi_final_df['title'] + '\n\n' + semi_final_df['content']

# 'title'과 'content' 열 삭제
semi_final2_df = semi_final_df.drop(['title', 'content'], axis=1)
# Out:
# <ipython-input-31-65fe3b8d5a66>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   semi_final_df['title_content'] = semi_final_df['title'] + '\n\n' + semi_final_df['content']

# %%
semi_final2_df.head()
# Out:
#   industry       date                                      title_content
# 0       건설 2023-11-23  해외EPC 3Q23 실발 분석: 한가닥씩 한 수주\n\n    3Q23 실적 분위기...
# 1       건설 2023-11-22  건설/부동산 Weekly\n\n    건설/부동산 Weekly News- '집값 2...
# 2       건설 2023-11-21  금리 하락에 상승한 주택주, 추격은 금물\n\n    주간 투자 전략 및 이슈 점검...
# 3       건설 2023-11-20  건설: 부동산 Weekly Data\n\n    이번주 Comment-전국 아파트 ...
# 4       건설 2023-11-15  건설/부동산 Weekly\n\n    건설/부동산 Weekly News- 서울 아파...

# %%
semi_final2_df.shape
# Out:
# (31451, 3)

# %%
# 'industry'와 'date' 열을 기준으로 그룹화하고 'title_content' 값을 합침
df_combined = semi_final2_df.groupby(['industry', 'date'])['title_content'].agg(lambda x: ' '.join(x)).reset_index()

# %%
df_combined.shape
# Out:
# (23806, 3)

# %%
df_combined.to_csv('/content/drive/MyDrive/tobigs_conference/report_crawling/csv_file/다수기사합친거.csv')

# %% [markdown]
# 다수기사합친거 파일이 한날에 여러 기사가 있는 경우 하나의 행으로 합쳐버렸다.

# %%
# 데이터 프레임 형태 바꿔주기(날짜가 행으로, 각 산업이 열로)
# Pivot table 생성
pivot_df = df_combined.pivot_table(index='date', columns='industry', values='title_content', aggfunc='first')

pivot_df.head()
# Out:
# industry     IT   건설  건자재   게임   광고   교육   금융   기계   기타   담배  ...   증권 지주회사  \
# date                                                          ...
# 2007-11-12  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN
# 2007-11-13  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN
# 2007-12-04  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN
# 2007-12-05  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN
# 2007-12-18  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN
#
# industry                                                 철강금속  타이어   통신 항공운송  \
# date
# 2007-11-12                                                NaN  NaN  NaN  NaN
# 2007-11-13                                                NaN  NaN  NaN  NaN
# 2007-12-04                                                NaN  NaN  NaN  NaN
# 2007-12-05  최근 세계 철강 시황 점검: 철강-강세, 비철-약세\n\n    철강금속 : 비중확...  NaN  NaN  NaN
# ...

# %%
# 인덱스를 열로 변환하여 날짜를 표시
pivot_df2 = pivot_df.reset_index()

# %%
pivot_df2.head()
# Out:
# industry       date   IT   건설  건자재   게임   광고   교육   금융   기계   기타  ...   증권  \
# 0        2007-11-12  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN
# 1        2007-11-13  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN
# 2        2007-12-04  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN
# 3        2007-12-05  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN
# 4        2007-12-18  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN
#
# industry 지주회사                                               철강금속  타이어   통신  \
# 0         NaN                                                NaN  NaN  NaN
# 1         NaN                                                NaN  NaN  NaN
# 2         NaN                                                NaN  NaN  NaN
# 3         NaN  최근 세계 철강 시황 점검: 철강-강세, 비철-약세\n\n    철강금속 : 비중확...  NaN  NaN
# 4         NaN                                                NaN  NaN  NaN
#
# industry 항공운송   해운  홈쇼핑  화장품  \
# 0         NaN  NaN  NaN  NaN
# ...

# %%
# 데이터프레임의 구조를 출력
print("데이터프레임의 구조:")
print(pivot_df2.shape)

# na가 아닌 값들의 개수를 출력
non_na_count = pivot_df2.count().sum()
print(f"\nna가 아닌 값들의 개수: {non_na_count}")
# Out:
# 데이터프레임의 구조:
# (3918, 43)
#
# na가 아닌 값들의 개수: 27724

# %%
pivot_df.to_csv('/content/drive/MyDrive/tobigs_conference/report_crawling/csv_file/realfinal_df.csv')
